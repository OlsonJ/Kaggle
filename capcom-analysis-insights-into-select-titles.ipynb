# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# '''
# 1/28/2026 - Project GOALS:
#                 - Expand data to rank 1 and rank 2 users
#                 - Users selected will be from different genres
#                 - ???
#                 - Create beautiful visualization of words tracked

# Twitch Chat Log Cleaner AND .txt -> .csv
# Author: Joshua Olson

# This Script will not work unless the .txt files are imported.
# I have not uploaded the original .txt files.

# Reference List: ----------------------------------------------------------------------------
#     - File Reading https://web.stanford.edu/class/archive/cs/cs106a/cs106a.1204/handouts/py-file.html

#     - glob         https://docs.python.org/3/library/glob.html
#     - nltk         https://www.nltk.org/ - (Natural Language Filtering Kit) -> Taken out of script on updated draft
                   
#     - re           https://docs.python.org/3/library/re.html
#                    https://www.geeksforgeeks.org/python/re-sub-python-regex/
#                    https://docs.python.org/3/howto/regex.html
                   
#     - os           https://docs.python.org/3/library/os.html#module-os
#       os.path      https://docs.python.org/3/library/os.path.html
                   
#     - collections  https://docs.python.org/3/library/collections.html
                   
#     - collections
#       counter      https://docs.python.org/3/library/collections.html#collections.Counter

# End of List: -------------------------------------------------------------------------------
# '''

# import glob
# import os
# import re
# from collections import Counter
# import pandas as pd

# class fileProcessor:
#     # ---------------------------------------------------------------
#     # 1. Setup
#     # ---------------------------------------------------------------
#     #     
#     top_n       = 60
#     bot_users   = {'streamelements', 'nightbot'}
#     folder_Path = r"C:\...\Twitch analysis\Swagg"              # Censored Out Original filepath
    
#     all_lines        = []                                      # Set groupcontainer 
#     messages         = [] 
#     cleaned_messages = []

#                                                                # Set message list
#     current_message = ""                                       # Set Current Message
#     current_user    = None                                     # Set User
#     current_date    = None                                     # Set Date
#     current_time    = None                                     # Set Time

#     # ---------------------------------------------------------------
#     # 1.5 - Regex for chat log formatting
#     # --------------------------------------------------------------- 
       
#     # Create Regex Object with re.compile()
#         # ^ = start of the line
#         # r - Raw String Literal 
#         # s - 
#         # a-z capture any lowercase
#         # A-Z capture any uppercase
#         # 0-9 capture any number
#         # d = digit
#         # \ - Regular expressions (Regex) use the backslash character ('\') 
#         #     to use special operators without invoking their special meaning


#     # Example:[2025-10-27 07:23:07 UTC] chikosburner: zoom out a bit
#     log_Pattern = (
#                     r'^\['                       
#                     r'(\d{4}-\d{2}-\d{2})'      # Group1 - "YYYY-MM-DD"      Date
#                     r' '                        #                            Whitespace
#                     r'(\d{2}:\d{2}:\d{2})'      # Group2 - "HH-MM-SS"        Time
#                     r' '                        #                            Whitespace
#                     r'([A-Z]{3})'               # Group3 - "UTC"             Time Zone
#                     r'\] '                      #                            bracket and whitespace
#                     r'([a-zA-Z0-9_]{4,25}): '   # Group4 -                   Username
#                    )  
#     message_start = re.compile(log_Pattern)

#     # ---------------------------------------------------------------
#     # 2. Process each chat log
#     # ---------------------------------------------------------------
 
#     # glob is for grabbing multiple files within a folder
#     # We use os.path to join all ".txt" files in folder
#     # "*.txt" the asterisk is a wild card symbol for capturing all input

#     input_folder = glob.glob(os.path.join(folder_Path, "*.txt"))
#     print(input_folder)
    
#     for file_path in input_folder:
#         print(f"\nProcessing file: {file_path}\n")

#         with open(file_path, "r", encoding="utf-8") as file:    #combine txt files
#             all_lines.extend(file.readlines())
#     ### ---END LOOP--- ###

#     for line in all_lines:                                       # Process lines
#         line = line.strip()                                      # Remove Whitespaces                 
#         match = message_start.match(line)                        # match to regex: log_pattern

#         if match:
#             date     = match.group(1)                            # Capture Date
#             time     = match.group(2)                            #   -     Time
#             username = match.group(4).lower()                    #   -     Username
            
#             if current_message and current_user not in bot_users:# Star message if not bot
#                 messages.append({
#                     "date"      :current_date,                   # Append Current_Date
#                     "time"      :current_time,                   #   -    Current_Time
#                     "user"      :current_user,                   #   -    Current_User
#                     "message"   :current_message.strip()})       #   -    Current_Message

#             if username not in bot_users:                        # Start new Message if not bot
#                 current_date    = date                           #   -    Date
#                 current_time    = time                           #   -    Time
#                 current_user    = username                       #   -    Username
#                 current_message = line[match.end():]             #   -    Message without group1-3

#             else:                                                # Delete Bot Message
#                 current_message = ""
#                 current_user = None
#         ### ---END Match Condition--- ###

#         else:
#             if current_user not in bot_users:
#                 current_message += " " + line
#         ### ---END LOOP--- ###
#     ### ---END LOOP--- ###

#     # After processing all lines, save message
#     if current_message and current_user not in bot_users:        # Add last message
#         messages.append({
#             "date"    : current_date,
#             "time"    : current_time,
#             "user"    : current_user,
#             "message" : current_message.strip()})

#     # ---------------------------------------------------------------
#     # 4. Create DataFrame and Export
#     # ---------------------------------------------------------------

#     df_messages   = pd.DataFrame(messages)
#     output_folder = os.path.dirname(file_path)
#     base_name     = os.path.basename(file_path)
#     output_name_messages = os.path.join(
#         output_folder, 
#         f"{os.path.splitext(base_name)[0]}_all_messages.csv")
    
#     df_messages.to_csv(output_name_messages, index=False)          #easier without index
#     print(f"Files exported to: {output_name_messages}")
# '''
# Bird, Steven, Edward Loper and Ewan Klein (2009), 
# Natural Language Processing with Python. O’Reilly Media Inc.


# '''
